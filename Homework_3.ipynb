# %% [markdown]
# # Домащнее задание 3
#
# ![image](images/{43BCB250-6DB7-406B-B575-FFE153B54CD3}.png)
#
# 1. Вывести ограничение для эпсилон в рекуррентной MAXNET
# 2. Прикрепленная задача + задать уравнения границ между классами
# 3. Придумать свою архитектуру компаратора на 3 входа, с меньшим числом нейронов, чем если объединять компараторы на 2 входа.
# 4. Предложить рекуррентную сеть MAXNET для произвольных чисел (положительных и отрицательных)
